# %% [markdown]
# # Projecto Zipline

# %% [markdown]
# ### Importamos todas las librerás requeridas y sus respectivos magics para buen funcionamiento

# %%
import datetime as dt
import pandas as pd
import pandas_datareader.data as web
import numpy as np
import matplotlib.pyplot as plt
import seaborn; seaborn.set()
from zipline.api import order, record, symbol
# %matplotlib notebook

# %% [markdown]
# ### Realizamos la importacion de los datos de 4 diferentes empresas para pruebas: Tesla, Google, Apple y Nvidia, y definimos el intervalo de tiempo

# %%
start = dt.datetime(2013,1,1)
end = dt.datetime(2017,12,31)
tsla = web.DataReader('TSLA','google',start,end)
goog = web.DataReader('GOOG','google',start,end)
appl = web.DataReader('AAPL','google',start,end)
nvda = web.DataReader('NVDA','google',start,end)
#plt.get_backend()
# Out:
# /home/jorge/anaconda3/lib/python3.6/site-packages/pandas_datareader/google/daily.py:40: UnstableAPIWarning:
# The Google Finance API has not been stable since late 2017. Requests seem
# to fail at random. Failure is especially common when bulk downloading.
#
#   warnings.warn(UNSTABLE_WARNING, UnstableAPIWarning)

# %% [markdown]
# ### Revisamos informacion de los datos recibidos

# %%
tsla.head()
# Out:
#              Open   High    Low  Close   Volume
# Date
# 2013-01-02  35.00  35.45  34.70  35.36  1194710
# 2013-01-03  35.18  35.45  34.75  34.77   741941
# 2013-01-04  34.80  34.80  33.92  34.40   673993
# 2013-01-07  34.80  34.80  33.90  34.34   441909
# 2013-01-08  34.50  34.50  33.11  33.68  1283985

# %%
tsla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1259 entries, 2013-01-02 to 2017-12-29
# Data columns (total 5 columns):
# Open      1259 non-null float64
# High      1259 non-null float64
# Low       1259 non-null float64
# Close     1259 non-null float64
# Volume    1259 non-null int64
# dtypes: float64(4), int64(1)
# memory usage: 59.0 KB

# %%
#tsla.to_csv('tsla.csv')
#appl.to_csv('appl.csv')
#goog.to_csv('goog.csv')
#nvda.to_csv('nvda.csv')

# %% [markdown]
# ### Graficamos los valores de apertura de cada empresa por separado y al final en un conjunto

# %%
plt.figure(1)
tsla_plot = plt.subplot()
#tsla_close = plt.subplot()
tsla_plot.plot(tsla['Close'],color='green')
plt.legend(['Tesla Close Value'],loc="upper left")
plt.title('Valores de Cierre Tesla')
# Out:
# <div id='14625355-f790-418a-8148-53d34bacb863'></div>

# %%
plt.figure(2)
goog_plot = plt.subplot()
goog_plot.plot(goog['Close'],color='blue')
plt.legend(['Google Close Value'],loc="upper left")
plt.title('Valores de Cierre Google')
# Out:
# <div id='8b2dd7b0-18e1-4388-9ec3-3603cbc77b59'></div>

# %%
plt.figure(3)
appl_plot = plt.subplot()
appl_plot.plot(appl['Close'],color='red')
plt.legend(['Apple Close Value'],loc="upper left")
plt.title('Valores de Cierre Apple')
# Out:
# <div id='15af660a-a8ea-46c9-a690-f02f92afb175'></div>

# %%
plt.figure(4)
nvda_plot = plt.subplot()
nvda_plot.plot(nvda['Close'],color='purple')
plt.legend(['Nvidia Close Value'],loc="upper left")
plt.title('Valores de Cierre Nvidia')
# Out:
# <div id='6f4c4343-7cf7-4690-b972-efe7ec51ff04'></div>

# %%
plt.figure(5)
tsla_plot=plt.subplot()
goog_plot=plt.subplot()
appl_plot=plt.subplot()
nvda_plot=plt.subplot()
tsla_plot.plot(tsla['Close'],color='green')
goog_plot.plot(goog['Close'],color='blue')
appl_plot.plot(appl['Close'],color='red')
nvda_plot.plot(nvda['Close'],color='purple')
plt.legend(['Tesla','Google','Apple','Nvidia'],loc="upper left")
plt.title('Valores de Cierre')
# Out:
# <div id='0beaa976-31c3-41bb-a7f8-985e7a38fd01'></div>

# %% [markdown]
# ### Revisamos si existen split's o merge's

# %% [markdown]
# Para encontrar de los splits y merge vamos a proceder de forma matematica para encontrar los posibles splits y merge.
#
# Primero creamos una nueva columna en la que iran la diferencia entre el valor Open y el valor Close.
#
# Sacamos el promedio de diferencia y la desviacion estandar, estadisticamente sabemos que todo lo que se aleje mas de 3 desviaciones estandar del promedio es un "outlier" es decir un dato fuera de lo normal, estos son los más probavles splits y merge.
#
# graficamos un histograma para ver la forma de los datos y creamos una lista que contenga estos outliers y otra que contenga la fecha de estos para poder revisar manualmente si fueron splits o merge o simplemente es un caso extraordinario.

# %%
def dif_open_close(symbol):
    diferencia= []
    for x in range(len(symbol['Open'])):
        diferencia.append(symbol['Open'][x]-symbol['Close'][x])
    return diferencia

# %%
def found_outliers(symbol):
    symbol['Cambio'] = dif_open_close(symbol)
    mean = symbol['Cambio'].mean()
    std = symbol['Cambio'].std()
    plt.figure('Histograma_Cambios')
    plt.hist(symbol['Cambio'],500)
    
    print('La media es: {}'.format(mean))
    print('La desviacion estandar es: {}'.format(std))
    
    idx = []
    vals = []
    for x in symbol['Cambio']:
        if x>=(mean+(std*3)) or x<=(mean-(std*3)):
            vals.append(x)
            idx.append(symbol.index[symbol['Cambio']==x])
            
            
    
    for x in vals:
        print(x)
        #print(symbol.index['Cambio'][x])
    for x in idx:
        print(x)

    
    
found_outliers(appl)
# Out:
# <div id='6f618cf5-d646-415a-bf3a-c63df8361a1d'></div>
# La media es: -0.009444003177124478
# La desviacion estandar es: 1.234299557681999
# 4.16
# 3.74
# -3.93
# 3.9
# 3.78
# 4.32
# 4.67
# -8.25
# 7.37
# 3.77
# -3.74
# -3.98
# 6.21
# 4.58
# -3.76
# DatetimeIndex(['2014-09-03'], dtype='datetime64[ns]', name='Date', freq=None)
# DatetimeIndex(['2014-12-01'], dtype='datetime64[ns]', name='Date', freq=None)
# DatetimeIndex(['2014-12-09'], dtype='datetime64[ns]', name='Date', freq=None)
# DatetimeIndex(['2015-04-28'], dtype='datetime64[ns]', name='Date', freq=None)
# DatetimeIndex(['2015-07-09'], dtype='datetime64[ns]', name='Date', freq=None)
# DatetimeIndex(['2015-08-11'], dtype='datetime64[ns]', name='Date', freq=None)
# DatetimeIndex(['2015-08-21'], dtype='datetime64[ns]', name='Date', freq=None)
# DatetimeIndex(['2015-08-24'], dtype='datetime64[ns]', name='Date', freq=None)
# DatetimeIndex(['2015-08-25'], dtype='datetime64[ns]', name='Date', freq=None)
# DatetimeIndex(['2015-09-29'], dtype='datetime64[ns]', name='Date', freq=None)
# DatetimeIndex(['2015-12-04'], dtype='datetime64[ns]', name='Date', freq=None)
# DatetimeIndex(['2017-05-08'], dtype='datetime64[ns]', name='Date', freq=None)
# DatetimeIndex(['2017-06-09'], dtype='datetime64[ns]', name='Date', freq=None)
# DatetimeIndex(['2017-08-10'], dtype='datetime64[ns]', name='Date', freq=None)
# DatetimeIndex(['2017-10-27'], dtype='datetime64[ns]', name='Date', freq=None)

# %% [markdown]
# ### Creamos los promedios moviles para empezar sera a 20 días

# %% [markdown]
# Para sacar el promedio movil creamos una funcion que toma dos parametros, el primero es la accion a revisar y el segundo es el numero de días del promedio movil.
# Esta nos regresa una lista con todos los valores del promedio movil.
# Continuamos graficando esto contra los valores de cierre de cada día y asi podemos ver cuando deberiamos comprar y cuando vender.

# %%
def prom_mov(symbol, dias = 20):
    list=[]
    suma_i = 0
    t=0
    suma_f = 0
    for x in range(dias-1):
        list.append(0)
    for i in range(len(symbol['Close'])-dias+1):
        suma_i = 0
        for j in range(dias):
            suma_i += symbol['Close'][i+j]
        t +=1
        prom1 = suma_i/dias
        suma_f += prom1
        list.append(prom1)
    promf = suma_f/t
    symbol['PromedioMov']= list
    print(symbol.head(21))
    
    
prom_mov(tsla,20)
# Out:
#              Open   High    Low  Close   Volume  PromedioMov
# Date
# 2013-01-02  35.00  35.45  34.70  35.36  1194710       0.0000
# 2013-01-03  35.18  35.45  34.75  34.77   741941       0.0000
# 2013-01-04  34.80  34.80  33.92  34.40   673993       0.0000
# 2013-01-07  34.80  34.80  33.90  34.34   441909       0.0000
# 2013-01-08  34.50  34.50  33.11  33.68  1283985       0.0000
# 2013-01-09  34.01  34.19  33.40  33.64   697979       0.0000
# 2013-01-10  33.87  33.99  33.38  33.53   922405       0.0000
# 2013-01-11  34.04  34.04  32.11  32.91  1563274       0.0000
# 2013-01-14  33.08  33.38  32.85  33.26   925018       0.0000
# 2013-01-15  33.11  34.25  33.08  33.90  1624389       0.0000
# 2013-01-16  33.85  34.23  33.73  34.10  1378138       0.0000
# 2013-01-17  34.16  34.85  33.92  34.38  1436604       0.0000
# 2013-01-18  34.74  34.78  33.82  34.52  3555074       0.0000
# 2013-01-22  34.56  35.55  34.26  35.19  1920131       0.0000
# 2013-01-23  35.02  36.24  34.96  36.00  1564206       0.0000
# 2013-01-24  36.00  37.72  35.84  36.99  1970389       0.0000
# 2013-01-25  37.00  37.54  36.80  36.98  1287703       0.0000
# 2013-01-28  36.86  38.71  36.86  38.03  1985992       0.0000
# 2013-01-29  38.10  38.44  37.13  37.95  1426503       0.0000
# 2013-01-30  37.85  38.00  37.43  37.52   968098      35.0725
# 2013-01-31  37.87  37.87  36.93  37.51   901318      35.1800

# %%
plt.figure(7)
tsla_pm = plt.subplot()
tsla_close = plt.subplot()
tsla_close.plot(tsla['Close'],color='green')
tsla_pm.plot(tsla['PromedioMov'],color='black',linestyle='--')
plt.legend(['Tesla Valor de Cierre','Promedio Movil'],loc="upper left")
plt.title('Valores de Cierre Tesla con Promedio Movil a 20 días')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Utilidad del promedio movil en esta accion

# %%
def utl_prom_mov(symbol,compra,startdate,enddate):
    accion1 = ""
    accion2 = ""
    acciones = 0
    costo = 0
    ganancia = 0
    contador_compra = 0
    contador_venta = 0
    for x in range(len(symbol['PromedioMov'])):
        if x == len(symbol['PromedioMov'])-1:
            pass
        elif symbol['PromedioMov'][x] <= symbol['Close'][x] and symbol['PromedioMov'][x] > symbol['Close'][x+1]:
            accion2 = 'Venta'
            contador_venta +=1
           
        elif symbol['PromedioMov'][x] >= symbol['Close'][x] and symbol['PromedioMov'][x] < symbol['Close'][x+1]:
            accion2 = 'Compra'
            contador_compra += 1 
        else:
            pass
        if accion1 == accion2:
            pass
        else:
            accion1 = accion2
            print(accion1)
            if accion1 == 'Compra':
                acciones += compra
                costo = acciones * symbol['Close'][x]
                print('Costo = {}'.format(costo))
            else:
                gananciaper = acciones * symbol['Close'][x]-costo
                ganancia += (acciones * symbol['Close'][x])-costo
                if acciones - compra <0:
                    acciones -= acciones
                else:
                    acciones -= compra
                print('Ganancia de periodo = {}'.format(gananciaper))
                print('Ganancia acumulada = {}'.format(ganancia))
            print(acciones)

utl_prom_mov(tsla,1,2,1)
# Out:
# Venta
# Ganancia de periodo = 0.0
# Ganancia acumulada = 0.0
# 0
# Compra
# Costo = 37.04
# 1
# Venta
# Ganancia de periodo = 1.5
# Ganancia acumulada = 1.5
# 0
# Compra
# Costo = 36.65
# 1
# Venta
# Ganancia de periodo = 2.3299999999999983
# Ganancia acumulada = 3.8299999999999983
# 0
# Compra
# Costo = 36.01
# 1
# Venta
# Ganancia de periodo = 64.03999999999999
# Ganancia acumulada = 67.86999999999999
# 0
# Compra
# Costo = 94.47
# 1
# Venta
# Ganancia de periodo = 6.180000000000007
# Ganancia acumulada = 74.05
# 0
# Compra
# Costo = 99.55
# 1
# Venta
# Ganancia de periodo = 27.710000000000008
# Ganancia acumulada = 101.76
# 0
# Compra
# Costo = 109.05
# 1
# Venta
# Ganancia de periodo = 71.89999999999999
# Ganancia acumulada = 173.66
# 0
# Compra
# Costo = 173.31
# 1
# Venta
# Ganancia de periodo = 9.759999999999991
# Ganancia acumulada = 183.42
# 0
# Compra
# Costo = 178.7
# 1
# Venta
# Ganancia de periodo = 4.700000000000017
# Ganancia acumulada = 188.12
# 0
# Compra
# Costo = 162.17
# 1
# Venta
# Ganancia de periodo = 14.640000000000015
# Ganancia acumulada = 202.76000000000002
# 0
# Compra
# Costo = 124.17
# 1
# Venta
# Ganancia de periodo = 27.11
# Ganancia acumulada = 229.87
# 0
# Compra
# Costo = 139.34
# 1
# Venta
# Ganancia de periodo = 98.44999999999999
# Ganancia acumulada = 328.32
# 0
# Compra
# Costo = 230.97
# 1
# Venta
# Ganancia de periodo = 9.069999999999993
# Ganancia acumulada = 337.39
# 0
# Compra
# Costo = 204.38
# 1
# Venta
# Ganancia de periodo = 14.259999999999991
# Ganancia acumulada = 351.65
# 0
# Compra
# Costo = 195.3
# 1
# Venta
# Ganancia de periodo = 33.94999999999999
# Ganancia acumulada = 385.59999999999997
# 0
# Compra
# Costo = 223.57
# 1
# Venta
# Ganancia de periodo = 55.629999999999995
# Ganancia acumulada = 441.22999999999996
# 0
# Compra
# Costo = 255.21
# 1
# Venta
# Ganancia de periodo = 1.799999999999983
# Ganancia acumulada = 443.03
# 0
# Compra
# Costo = 221.67
# 1
# Venta
# Ganancia de periodo = 21.100000000000023
# Ganancia acumulada = 464.13
# 0
# Compra
# Costo = 230.97
# 1
# Venta
# Ganancia de periodo = 17.74000000000001
# Ganancia acumulada = 481.87
# 0
# Compra
# Costo = 242.78
# 1
# Venta
# Ganancia de periodo = 5.659999999999997
# Ganancia acumulada = 487.53
# 0
# Compra
# Costo = 220.97
# 1
# Venta
# Ganancia de periodo = -1.6599999999999966
# Ganancia acumulada = 485.87
# 0
# Compra
# Costo = 199.37
# 1
# Venta
# Ganancia de periodo = 5.829999999999984
# Ganancia acumulada = 491.7
# 0
# Compra
# Costo = 204.46
# 1
# Venta
# Ganancia de periodo = 12.650000000000006
# Ganancia acumulada = 504.35
# 0
# Compra
# Costo = 194.73
# 1
# Venta
# Ganancia de periodo = 5.980000000000018
# Ganancia acumulada = 510.33000000000004
# 0
# Compra
# Costo = 191.0
# 1
# Venta
# Ganancia de periodo = 76.88
# Ganancia acumulada = 587.21
# 0
# Compra
# Costo = 262.16
# 1
# Venta
# Ganancia de periodo = 3.4899999999999523
# Ganancia acumulada = 590.7
# 0
# Compra
# Costo = 263.14
# 1
# Venta
# Ganancia de periodo = 19.120000000000005
# Ganancia acumulada = 609.82
# 0
# Compra
# Costo = 266.77
# 1
# Venta
# Ganancia de periodo = 1.1000000000000227
# Ganancia acumulada = 610.9200000000001
# 0
# Compra
# Costo = 263.82
# 1
# Venta
# Ganancia de periodo = 2.9700000000000273
# Ganancia acumulada = 613.8900000000001
# 0
# Compra
# Costo = 259.99
# 1
# Venta
# Ganancia de periodo = 10.139999999999986
# Ganancia acumulada = 624.0300000000001
# 0
# Compra
# Costo = 254.99
# 1
# Venta
# Ganancia de periodo = 5.730000000000018
# Ganancia acumulada = 629.7600000000001
# 0
# Compra
# Costo = 242.99
# 1
# Venta
# Ganancia de periodo = 6.069999999999993
# Ganancia acumulada = 635.8300000000002
# 0
# Compra
# Costo = 238.63
# 1
# Venta
# Ganancia de periodo = 18.28000000000003
# Ganancia acumulada = 654.1100000000001
# 0
# Compra
# Costo = 208.35
# 1
# Venta
# Ganancia de periodo = 16.980000000000018
# Ganancia acumulada = 671.0900000000001
# 0
# Compra
# Costo = 216.5
# 1
# Venta
# Ganancia de periodo = 2.5800000000000125
# Ganancia acumulada = 673.6700000000002
# 0
# Compra
# Costo = 214.0
# 1
# Venta
# Ganancia de periodo = 13.069999999999993
# Ganancia acumulada = 686.7400000000002
# 0
# Compra
# Costo = 221.09
# 1
# Venta
# Ganancia de periodo = 9.47999999999999
# Ganancia acumulada = 696.2200000000003
# 0
# Compra
# Costo = 166.58
# 1
# Venta
# Ganancia de periodo = 84.88999999999999
# Ganancia acumulada = 781.1100000000002
# 0
# Compra
# Costo = 212.28
# 1
# Venta
# Ganancia de periodo = 4.219999999999999
# Ganancia acumulada = 785.3300000000003
# 0
# Compra
# Costo = 226.16
# 1
# Venta
# Ganancia de periodo = 2.920000000000016
# Ganancia acumulada = 788.2500000000002
# 0
# Compra
# Costo = 205.22
# 1
# Venta
# Ganancia de periodo = 1.0500000000000114
# Ganancia acumulada = 789.3000000000002
# 0
# Compra
# Costo = 200.7
# 1
# Venta
# Ganancia de periodo = 7.760000000000019
# Ganancia acumulada = 797.0600000000002
# 0
# Compra
# Costo = 199.1
# 1
# Venta
# Ganancia de periodo = 4.460000000000008
# Ganancia acumulada = 801.5200000000002
# 0
# Compra
# Costo = 200.09
# 1
# Venta
# Ganancia de periodo = 3.9199999999999875
# Ganancia acumulada = 805.4400000000002
# 0
# Compra
# Costo = 184.52
# 1
# Venta
# Ganancia de periodo = 4.8799999999999955
# Ganancia acumulada = 810.3200000000002
# 0
# Compra
# Costo = 185.85
# 1
# Venta
# Ganancia de periodo = 87.66
# Ganancia acumulada = 897.9800000000001
# 0
# Compra
# Costo = 255.73
# 1
# Venta
# Ganancia de periodo = 6.190000000000026
# Ganancia acumulada = 904.1700000000002
# 0
# Compra
# Costo = 250.68
# 1
# Venta
# Ganancia de periodo = 60.339999999999975
# Ganancia acumulada = 964.5100000000002
# 0
# Compra
# Costo = 295.46
# 1
# Venta
# Ganancia de periodo = 12.890000000000043
# Ganancia acumulada = 977.4000000000003
# 0
# Compra
# Costo = 307.19
# 1
# Venta
# Ganancia de periodo = 9.819999999999993
# Ganancia acumulada = 987.2200000000003
# 0
# Compra
# Costo = 306.11
# 1
# Venta
# Ganancia de periodo = 71.38
# Ganancia acumulada = 1058.6000000000004
# 0
# Compra
# Costo = 362.37
# 1
# Venta
# Ganancia de periodo = 8.870000000000005
# Ganancia acumulada = 1067.4700000000003
# 0
# Compra
# Costo = 328.4
# 1
# Venta
# Ganancia de periodo = 6.670000000000016
# Ganancia acumulada = 1074.1400000000003
# 0
# Compra
# Costo = 325.89
# 1
# Venta
# Ganancia de periodo = 27.04000000000002
# Ganancia acumulada = 1101.1800000000003
# 0
# Compra
# Costo = 347.36
# 1
# Venta
# Ganancia de periodo = 8.039999999999964
# Ganancia acumulada = 1109.2200000000003
# 0
# Compra
# Costo = 343.4
# 1
# Venta
# Ganancia de periodo = 23.08000000000004
# Ganancia acumulada = 1132.3000000000002
# 0
# Compra
# Costo = 350.6
# 1
# Venta
# Ganancia de periodo = 1.2099999999999795
# Ganancia acumulada = 1133.5100000000002
# 0
# Compra
# Costo = 308.74
# 1
# Venta
# Ganancia de periodo = 9.069999999999993
# Ganancia acumulada = 1142.5800000000002
# 0
# Compra
# Costo = 303.7
# 1
# Venta
# Ganancia de periodo = 21.5
# Ganancia acumulada = 1164.0800000000002
# 0

# %% [markdown]
# ### Sacaremos el porcentaje de cambio diario

# %%
def pct_cambio(symbol):
    symbol['Pct Cambio'] =symbol['Close'].pct_change()
    symbol['Pct Cambio'].fillna(0, inplace=True)
    print(symbol.head())
    
pct_cambio(appl)

# %%
# %load_ext zipline

# %%
#%%zipline --start 2013-1-1 --end 2017-12-31
#%%zipline --start 2000-1-1 --end 2014-1-1

# %%
def initialize(context):
    pass

def handle_data(context, data):
    order(symbol('AAPL'), 10)
    record(AAPL=data[symbol('AAPL')].price)
